# %%
import pandas as pd

# %%
pokemons_df = pd.read_json("../databases/smogon_metagame_data/chaos_gen9championsvgc2026regmbbo3-1760.json")
dados_por_pokemon = pokemons_df["data"].dropna()

info = ["Abilities","Items", "Spreads","Moves","Teammates"]
pokemon_nome = "Kingambit"

for i in info:
    if i == "Spreads":
        print(dados_por_pokemon[pokemon_nome][i].sort())
    print(dados_por_pokemon[pokemon_nome][i])
# Out:
# {'defiant': 15290.29826982518, 'supremeoverlord': 2.529562309966367, 'pressure': 1.555938089481401e-08}
# {'focussash': 1358.3545351438004, 'chopleberry': 4353.098698980985, 'blackglasses': 2895.5888977202026, 'lifeorb': 4977.907776672376, 'expertbelt': 100.6278033809067, 'kingsrock': 2.8665812074000002e-05, 'occaberry': 1591.295147432135, 'whiteherb': 1.0492283519e-05, 'blackbelt': 3.8611413934932, 'mentalherb': 0.000548914644223, 'nothing': 0.557436358968031, 'leftovers': 0.7093368093486601, 'sitrusberry': 9.567902457389705, 'shucaberry': 0.209662878737777, 'wiseglasses': 0.00027476868470400004, 'muscleband': 0.032724741209693, 'lumberry': 0.0033048744919110004, 'choicescarf': 0.8967916848717231, 'shellbell': 0, 'quickclaw': 0.0069060967161070005, 'metalcoat': 0.000178653379743, 'sceptilite': 0.027954321704197004, 'chilanberry': 0.07961853591298301, 'roseliberry': 5.499291063082445e-07, 'charcoal': 0, 'colburberry': 0, 'lightball': 2.1069035727000003e-05, 'scopelens': 0, 'cobaberry': 0.0011295537104520001, 'brightpowder': 0, 'blastoisinite': 0}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 9
#       7 for i in info:
#       8     if i == "Spreads":
# ----> 9         print(dados_por_pokemon[pokemon_nome][i].sort())
#      10     print(dados_por_pokemon[pokemon_nome][i])
#
# AttributeError: 'dict' object has no attribute 'sort'
